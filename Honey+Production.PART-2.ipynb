# %%
#1. Import required libraries and read the dataset.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/honeyproduction.csv')

# %%
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
#2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
df.head(5)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.tail(5)
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
df.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %%
#3. Display the percentage distribution of the data in each year using the pie chart.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
per=df.groupby('year').size()/len(df)*100

# %%
plt.figure(figsize=(5,5))
plt.pie(per,labels=per.index,autopct='%1.1f%%')
plt.show()

# %%
#4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['priceperlb'])
plt.title('The Distribution of the variable')
# Out:
# <ipython-input-39-33ddd279acd8>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['priceperlb'])
# Text(0.5, 1.0, 'The Distribution of the variable')

# %% [markdown]
# Findings:
# 1.The plot will show the distribution of the "price per lb".
# 2.I can observe the shape of the distribution
# 3.The KDE curve gives you an estimate of the underlying probability density.
# 4.I can see the range of prices and where the data is concentrated.

# %%
# 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
plt.figure(figsize=(5,5))
plt.scatter(x='numcol',y='prodvalue',data=df,color='b')

# %% [markdown]
# Findings:
# 1.The scatterplot will visually represent the relationship between 'numcol' and 'prodval'.

# %%
#6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='year', y='prodvalue', data=df)
# Out:
# <Axes: xlabel='year', ylabel='prodvalue'>

# %% [markdown]
# Findings:
# 1.The boxplot displays the distribution of 'prodvalue' for each year.
# 2.It shows where the middle 50% of the data lies.
# The line inside the box represents the median (middle) value of 'prodvalue' for each year.
# 3.This visualization will help you understand how 'prodvalue' is distributed across different years and whether there are any significant differences or trends over time.

# %%
#7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(df[['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year']])

# %% [markdown]
# Inference:
# 1.The pairplot allows you to visualize the relationships between multiple pairs of variables across different years.
# 2.Each subplot within the pairplot represents a scatterplot for one pair of variables.
# 3.The color differentiation by 'year' helps identify trends or patterns specific to each year.
# 4.You can look for patterns such as correlations, clusters, or outliers.

# %%
#8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
sns.heatmap(df[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']].corr())
# Out:
# <Axes: >

# %% [markdown]
# Inference:
# 1.The heatmap provides a visual representation of the correlation matrix, where each cell represents the correlation coefficient between two variables.
# 2.Correlation coefficients range from -1 (perfect negative correlation) to 1 (perfect positive correlation), with 0 indicating no linear correlation.
# 3.In this heatmap, positive correlations are shown in warmer colors, while negative correlations are in cooler colors.
